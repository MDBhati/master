# %% [markdown]
# <a href="https://colab.research.google.com/github/MDBhati/master/blob/main/Data_Visualization_with_Matplotlib_%26_Seaborn_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🎉 Hi there! Welcome to today's assignment on Data Visualization with Matplotlib and Seaborn in Python!
#
# Are you ready to put your skills to the test? Let's dive right in! 💪📚
#
# In this assignment, you will be working with Data Visualization with Matplotlib and Seaborn in Python . Don't worry if you're feeling a bit unsure - you got this! 🤞
#
# Good luck! 🍀🚀

# %% [markdown]
# #### All the datasets required for this assignment can be found here: https://drive.google.com/drive/folders/1e9JX6rBQyQM-dqWHgGuOicydb2rfpmM6?usp=sharing
#
# #### You can download the data and start working with the assignment.

# %% [markdown]
# ## **Activity 1:**

# %% [markdown]
# ### **Netflix Movies and TV Shows:**
#
# The dataset contains information about movies and TV shows available on Netflix as of 2021. Your task is to perform the following actions based on the data:
#
# 1. Identify missing values: Check if there are any missing values in the dataset and decide how to handle them. For example, if the "director" column has missing values, we can either delete those rows or fill in the missing values with "unknown".
#
# 2. Data Cleaning: Clean the dataset to remove any duplicates, inconsistencies or irrelevant columns. For example, we can remove the "show_id" and "description" columns as they may not be relevant for our analysis.
#
# 3. Data Exploration: Use Matplotlib to create visualizations that explore the data in meaningful ways. For example, we can create a bar chart to show the number of movies vs TV shows available on Netflix, or a line chart to show the trend in the number of new titles added each year.
#
# 4. Analyze Genres: Analyze the genres of movies and TV shows available on Netflix using bar charts or pie charts. For example, we can create a bar chart to show the top 10 most popular genres on Netflix.
#
# 5. Analyze Ratings: Analyze the ratings of movies and TV shows available on Netflix using histograms or box plots. For example, we can create a histogram to show the distribution of ratings on Netflix.
#
# 6. Insights and Conclusions: Based on the visualizations created, draw insights and conclusions about the dataset. For example, we may find that Netflix has a larger selection of TV shows than movies, or that the most popular genres on Netflix are drama and comedy.

# %% [markdown]
# ![netflix (1).png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
# Write your code here
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/Datasets/netflix_titles.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Data Cleaning: Clean the dataset to remove any duplicates, inconsistencies or irrelevant columns. For example, we can remove the "show_id" and "description" columns as they may not be relevant for our analysis.

# %%
netflix = df.drop(['show_id','description'],axis=1)

# %%
netflix = netflix.drop_duplicates()

# %%
# understand variables
variables = pd.DataFrame(columns=['variable','Number of unique values','Values'])

for i,var in enumerate(netflix.columns):
  variables.loc[i] = [var,netflix[var].nunique(),netflix[var].unique()]

variables
# Out:
#        variable  Number of unique values  \
# 0          type                        2
# 1         title                     8807
# 2      director                     4528
# 3          cast                     7692
# 4       country                      748
# 5    date_added                     1767
# 6  release_year                       74
# 7        rating                       17
# 8      duration                      220
# 9     listed_in                      514
#
#                                               Values
# 0                                   [Movie, TV Show]
# 1  [Dick Johnson Is Dead, Blood & Water, Gangland...
# 2  [Kirsten Johnson, nan, Julien Leclercq, Mike F...
# 3  [nan, Ama Qamata, Khosi Ngema, Gail Mabalane, ...
# 4  [United States, South Africa, nan, India, Unit...
# 5  [September 25, 2021, September 24, 2021, Septe...
# 6  [2020, 2021, 1993, 2018, 1996, 1998, 1997, 201...
# 7  [PG-13, TV-MA, PG, TV-14, TV-PG, TV-Y, TV-Y7, ...
# ...

# %%
netflix.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# Q.1 Identify missing values: Check if there are any missing values in the dataset and decide how to handle them. For example, if the "director" column has missing values, we can either delete those rows or fill in the missing values with "unknown".

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 756.9+ KB

# %%
netflix.isna().sum()  # #  Director, cast, country, date_added, rating and duration Columns have null values.
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# dtype: int64

# %%
netflix['director']  = netflix['director'].fillna('unknown')
netflix['cast']  = netflix['cast'].fillna('unknown')
netflix['country']  = netflix['country'].fillna('unknown')
netflix['date_added']  = netflix['date_added'].fillna(netflix['release_year'],axis=0)
netflix['rating'] = netflix['rating'].fillna('unknown')

# %%
netflix.isna().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# dtype: int64

# %%
netflix['duration'] = netflix['duration'].str.replace(' min','')
netflix['duration'] = netflix['duration'].str.replace(' seasons','')

# %%
netflix.shape
# Out:
# (8807, 10)

# %% [markdown]
# Q.3 Data Exploration: Use Matplotlib to create visualizations that explore the data in meaningful ways. For example, we can create a bar chart to show the number of movies vs TV shows available on Netflix, or a line chart to show the trend in the number of new titles added each year.

# %%
x = netflix['type'].unique()
y = netflix['type'].value_counts().values

# %%
# 3. Data Exploration
# Bar plot showing numbers of TV shows vs movies
plt.bar(x,y)
plt.xlabel('Type',fontsize=1)
plt.ylabel('Count',fontsize=12)
plt.title('Count of Movies and TV Shows')
plt.show()

# %%
netflix['date_added'] = pd.to_datetime(netflix['date_added'])
netflix['year_added'] = netflix['date_added'].dt.year

# %%
movies = netflix[netflix['type']=='Movie']
tv_shows = netflix[netflix['type']=='TV Show']

# %%
movies_added_year  = movies.year_added.value_counts()
tv_show_added_year = tv_shows.year_added.value_counts()

# %%
plt.plot(movies_added_year.index,movies_added_year.values)
plt.xlabel("Year",fontsize=12)
plt.ylabel('Count')
plt.title("Number of movies added on Netflix")
plt.show()

# %%
plt.plot(tv_show_added_year.index,tv_show_added_year.values,marker='o')
plt.xlabel("Year",fontsize=12)
plt.ylabel('Count')
plt.title("Number of TV Shows added on Netflix")
plt.show()
plt.show()

# %% [markdown]
# Q.4 Analyze Genres: Analyze the genres of movies and TV shows available on Netflix using bar charts or pie charts. For example, we can create a bar chart to show the top 10 most popular genres on Netflix.

# %%
top10_movie_genre = movies.listed_in.value_counts().head(10)
top10_movie_genre_sort =top10_movie_genre.sort_values()

# %%
plt.figure(figsize=(15,8))
plt.barh(top10_movie_genre_sort.index,top10_movie_genre_sort.values)
plt.xlabel('Number of movies',fontsize=15)
plt.ylabel('genre',fontsize=15)
plt.title('Number of movies by genre',fontsize=22)
plt.show()

# %%
top10_tv_shows_genre = tv_shows.listed_in.value_counts().head(10)
top10_tv_shows_genre_sort = top10_tv_shows_genre.sort_values()

# %%
plt.figure(figsize=(15,8))
plt.barh(top10_tv_shows_genre_sort.index,top10_tv_shows_genre_sort.values)
plt.xlabel('Number of TV Shows',fontsize=15)
plt.ylabel('genre',fontsize=15)
plt.title('Number of TV Shows by genre',fontsize=22)
plt.show()

# %% [markdown]
# Q.5 Analyze Ratings: Analyze the ratings of movies and TV shows available on Netflix using histograms or box plots. For example, we can create a histogram to show the distribution of ratings on Netflix.

# %%
rating = netflix.groupby('rating').agg(rating_count = ('rating','count')).sort_values('rating_count',ascending=False)
rating
# Out:
#           rating_count
# rating
# TV-MA             3207
# TV-14             2160
# TV-PG              863
# R                  799
# PG-13              490
# TV-Y7              334
# TV-Y               307
# PG                 287
# TV-G               220
# NR                  80
# G                   41
# TV-Y7-FV             6
# unknown              4
# NC-17                3
# UR                   3
# 74 min               1
# 84 min               1
# 66 min               1

# %%
plt.figure(figsize=(14,7),dpi=150)
graph = sns.countplot(data=netflix,x='rating',order=rating.index)
plt.xticks(rotation=90)

for p in graph.patches:
  height = p.get_height()
  graph.text(p.get_x() + p.get_width()/2, height+20,height,ha='center',fontsize=8)

text = 'Top 3 most used rating :\n\n   1. TV-MA\n   2. TV-14\n   3. TV-PG'
plt.text(5,2500,text,horizontalalignment='left',fontsize=14,fontstyle='italic')
plt.title('Rating across Netflix',weight='semibold',fontsize=22)
plt.show()

# %% [markdown]
# Q.6 Insights and Conclusions: Based on the visualizations created, draw insights and conclusions about the dataset. For example, we may find that Netflix has a larger selection of TV shows than movies, or that the most popular genres on Netflix are drama and comedy.

# %%
# 1. On Netflix there are movies has larger selection than TV shows.
# 2. most popular genre in movie category is Dramas and international movies.
# 3. In TV shows category most popular genre is kid's TV.
# 4. On netflix there are so many movies and TV shows added exponentially after 2015
# 5 .most rating on Netflix is  TV-MA .

# %% [markdown]
# ## **Activity 2:**

# %% [markdown]
# ### **US Accidents:**
#
# For this activity, we will be using the "US Accidents" dataset. The dataset contains information about traffic accidents in the United States from 2016 to 2020.
#
# 👉 Instructions:
# 1. Load the dataset into a pandas DataFrame and check for missing values.
#
# 2. Identify the top 10 states with the highest number of accidents and create a bar chart using matplotlib to visualize the data.
#
# 3. Create a scatter plot of the longitude and latitude columns to show the location of accidents.
#
# 4. Identify the top 10 cities with the highest number of accidents and create a horizontal bar chart using matplotlib to visualize the data.
#
# 5. Create a pie chart to show the distribution of accidents by severity (use the 'Severity' column).
#
# 6. Create a line chart to show the trend of accidents over time (use the 'Start_Time' column).
#
# 7. Identify any outliers or inconsistencies in the data and decide how to handle them.
#
# Note:
# You may need to clean the data before visualizing it, as it contains missing values and inconsistent formats. Some of the columns may also need to be converted to the appropriate data types before they can be visualized.

# %% [markdown]
# ![accident-insurance.png](data:image/png;base64,...)

# %% [markdown]
# Q.1 Load the dataset into a pandas DataFrame and check for missing values.

# %%
# Write your code here
# loading of the dataset into dataframe
import pandas as pd
us_data_path = "/content/drive/My Drive/Colab Notebooks/Datasets/US_Accidents_Dec21_updated.csv"
accident = pd.read_csv(us_data_path)

# %%
accident.head() #first five rows
# Out:
#     ID  Severity          Start_Time            End_Time  Start_Lat  \
# 0  A-1         3 2016-02-08 00:37:08 2016-02-08 06:37:08  40.108910
# 1  A-2         2 2016-02-08 05:56:20 2016-02-08 11:56:20  39.865420
# 2  A-3         2 2016-02-08 06:15:39 2016-02-08 12:15:39  39.102660
# 3  A-4         2 2016-02-08 06:51:45 2016-02-08 12:51:45  41.062130
# 4  A-5         3 2016-02-08 07:53:43 2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
# check for missing value
accident.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1743911
# Street                         2
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1319
# Country                        0
# Timezone                    3659
# Airport_Code                9549
# Weather_Timestamp          50736
# Temperature(F)             69274
# Wind_Chill(F)             469643
# Humidity(%)                73092
# Pressure(in)               59200
# Visibility(mi)             70546
# Wind_Direction             73775
# Wind_Speed(mph)           157944
# ...

# %% [markdown]
# All the data is not useful for us .I will  take those columns which are useful for my analysis.

# %%
accident.shape
# Out:
# (2845342, 47)

# %% [markdown]
# Q.2 Identify the top 10 states with the highest number of accidents and create a bar chart using matplotlib to visualize the data.

# %%
top10_state = accident[['ID','State']]
top10_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   ID      object
#  1   State   object
# dtypes: object(2)
# memory usage: 43.4+ MB

# %%
state_wise_accident = top10_state.groupby('State').agg(Total_accidents = ('ID','count')).sort_values("Total_accidents",ascending=False).head(10)

# %%
state_wise_accident
# Out:
#        Total_accidents
# State
# CA              795868
# FL              401388
# TX              149037
# OR              126341
# VA              113535
# NY              108049
# PA               99975
# MN               97185
# NC               91362
# SC               89216

# %%
plt.figure(figsize=(12,6),dpi=200)
plt.bar(state_wise_accident.index,state_wise_accident['Total_accidents'])
plt.xlabel("State")
plt.ylabel("Total No. of accidents")
plt.title("State wise total accident",fontsize=20)
text2 = 'Top 3 State which had most severity: \n\n  1.CA \n  2.FL \n  3.TX'
plt.text(4,600000,text2,horizontalalignment='left',fontsize=12,fontstyle='italic')
plt.show()

# %% [markdown]
# Q.3 Create a scatter plot of the longitude and latitude columns to show the location of accidents.

# %%
location = accident[['Start_Lat','Start_Lng','State']]
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Start_Lat  float64
#  1   Start_Lng  float64
#  2   State      object
# dtypes: float64(2), object(1)
# memory usage: 65.1+ MB

# %%
plt.figure(figsize=(11,6))
sns.scatterplot(data= location,x='Start_Lng',y='Start_Lat',hue='State')

# Specify the location for the legend
legend_location = 'upper left'

# Get the current axes and legend
ax = plt.gca()
legend = ax.legend()

# Set the legend location
legend.set_bbox_to_anchor((1, 1))
plt.show()

# %% [markdown]
# Q.4 Identify the top 10 cities with the highest number of accidents and create a horizontal bar chart using matplotlib to visualize the data.

# %%
cities = accident[['Severity','City']]

# %%
top10_cities = cities.groupby('City').agg(total_accident = ("Severity","count")).sort_values("total_accident",ascending=False).head(10)

# %%
top10_cities_sort  = top10_cities.sort_values("total_accident")
top10_cities_sort
# Out:
#              total_accident
# City
# Minneapolis           22768
# Raleigh               22840
# San Diego             26627
# Sacramento            32559
# Charlotte             33152
# Houston               39448
# Dallas                41979
# Orlando               54691
# Los Angeles           68956
# Miami                106966

# %%
plt.figure(figsize=(12,6),dpi=150)
plt.barh(top10_cities_sort.index,top10_cities_sort['total_accident'])
plt.xlabel("total no. of accidents")
plt.ylabel("City")
plt.title("Top 10 City wise total accident",fontsize=20)
text = 'Top 3 cities which had occured most severity :  \n\n      1.Miami : has 1.06 million severity\n      2.Los Angeles : has 0.69 million severity\n      3.Orlando : has 0.55 million severity'
plt.text(60000,3,text,horizontalalignment='left',fontsize=12,fontstyle='italic')
plt.show()

# %% [markdown]
# Q.5 Create a pie chart to show the distribution of accidents by severity (use the 'Severity' column).

# %%
sever = accident[['Severity']].value_counts().sort_index()
sever
# Out:
# Severity
# 1             26053
# 2           2532991
# 3            155105
# 4            131193
# dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.pie(sever.values,labels=sever.index,autopct="%0.2f%%",textprops={"fontsize":15},colors=['c','y','r','brown'],pctdistance=0.75)
plt.legend()
plt.show()

# %% [markdown]
# Q.6 Create a line chart to show the trend of accidents over time (use the 'Start_Time' column).

# %%
trend = accident[['ID','Start_Time']]
trend['Start_Time'] = pd.to_datetime(trend['Start_Time'])
trend['year']  = pd.to_datetime(trend['Start_Time']).dt.year
trend.info()
# Out:
# <ipython-input-140-66d4c6e8fea3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trend['Start_Time'] = pd.to_datetime(trend['Start_Time'])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ID          object
#  1   Start_Time  datetime64[ns]
#  2   year        int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 65.1+ MB
# <ipython-input-140-66d4c6e8fea3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
trend_over_time  = trend.groupby('year').agg(total_accidents = ('ID',"count"))
trend_over_time
# Out:
#       total_accidents
# year
# 2016           122024
# 2017           163918
# 2018           163176
# 2019           258615
# 2020           625864
# 2021          1511745

# %%
plt.plot(trend_over_time.index,trend_over_time.values,marker='o')
plt.xlabel('Year',fontsize=12)
plt.ylabel("Total accidents in millions",fontsize=12)
plt.title('Total accidents over the period of time',fontsize=15)
plt.show()

# %% [markdown]
# ## **Activity 3:**

# %% [markdown]
# ### **Dataset Information:**
#
# For this activity, we will use the "Titanic: Machine Learning from Disaster" dataset, which contains information about passengers on the Titanic, including their age, gender, class, fare, and survival status.
#
# ### **Data Visualization Task:**
#
# Your task is to create a data visualization using Seaborn to explore the relationship between age, gender, and survival status of the passengers on the Titanic. Perform the following actions based on the data:
#
# 1. Identify missing values: Check for any missing values in the Age column.
#
# 2. Fill in missing values: If there are missing values in the Age column, use appropriate techniques such as imputation or interpolation to fill in the missing values.
#
# 3. Inconsistent formats: Check if there are any inconsistencies in the formatting of the gender column. For example, if the gender is encoded as "male" and "female", ensure that it is consistent throughout the dataset.
#
# 4. Standardize data types: Convert the data type of the Age column to numeric (float or integer) if necessary.
#
# 5. Identify and handle outliers or inconsistencies: Use Seaborn to create visualizations such as box plots or scatter plots to identify any outliers or inconsistencies in the data related to age, gender, and survival status.
#
# 6. Create data visualizations: Use Seaborn to create appropriate visualizations such as bar charts, count plots, or heatmaps to explore the relationship between age, gender, and survival status of the passengers on the Titanic.
#
# 7. Interpretation: Based on the visualizations, draw conclusions and insights about the relationship between age, gender, and survival status of the passengers on the Titanic.
#
# **Note:** You can use Seaborn functions such as countplot(), barplot(), boxplot(), scatterplot(), heatmap(), etc. to create the visualizations. Use appropriate Seaborn styling options such as color palettes, font sizes, and plot styles to make the visualizations visually appealing and informative.
#
# Remember to provide proper labels and titles for the visualizations, and include necessary comments or explanations in your code to explain your thought process and interpretation of the results.

# %% [markdown]
# ![cruise.png](data:image/png;base64,...)

# %%
# Write your code here
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
variables = pd.DataFrame(columns=['variable',"Number of unique values",'Values'])
for i,var in enumerate(titanic.columns):
  variables.loc[i] = [var,titanic[var].nunique(),titanic[var].unique()]

variables
# Out:
#        variable  Number of unique values  \
# 0      survived                        2
# 1        pclass                        3
# 2           sex                        2
# 3           age                       88
# 4         sibsp                        7
# 5         parch                        7
# 6          fare                      248
# 7      embarked                        3
# 8         class                        3
# 9           who                        3
# 10   adult_male                        2
# 11         deck                        7
# 12  embark_town                        3
# 13        alive                        2
# 14        alone                        2
#
#                                                Values
# 0                                              [0, 1]
# 1                                           [3, 1, 2]
# 2                                      [male, female]
# 3   [22.0, 38.0, 26.0, 35.0, nan, 54.0, 2.0, 27.0,...
# ...

# %% [markdown]
# Q.1 Identify missing values: Check for any missing values in the Age column.

# %%
titanic.isna().sum()  # finding missing values in the dataset
# in age column 177 values are missing
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Q.2 Fill in missing values: If there are missing values in the Age column, use appropriate techniques such as imputation or interpolation to fill in the missing values.

# %%
class_age_dict  = dict(titanic.groupby('pclass')['age'].mean().round())
class_age_dict  # class 1 mean age 38 year ,class2 mean age 30 and class3 passenger mean age is 25
# Out:
# {1: 38.0, 2: 30.0, 3: 25.0}

# %%
titanic[titanic['age'].isna()].value_counts('pclass')  # class wise missing values in age column
# Out:
# pclass
# 3    136
# 1     30
# 2     11
# dtype: int64

# %%
titanic['age']  = titanic['age'].fillna(titanic['pclass'].map(class_age_dict))
# fill age column missing value with respect to their passenger class mean age

# %%
titanic['age'].isna().sum()
# Out:
# 0

# %% [markdown]
# Q.3 Inconsistent formats: Check if there are any inconsistencies in the formatting of the gender column. For example, if the gender is encoded as "male" and "female", ensure that it is consistent throughout the dataset.

# %%
titanic['sex'].unique()  # sex column is consistent throughout the dataset i.e there is no other values except 'male' and 'female'.
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# Q.4 Standardize data types: Convert the data type of the Age column to numeric (float or integer) if necessary.

# %%
titanic['age'].dtype # datatype of age column is float64 so there is no need to change.
# Out:
# dtype('float64')

# %% [markdown]
# Q.5 Identify and handle outliers or inconsistencies: Use Seaborn to create visualizations such as box plots or scatter plots to identify any outliers or inconsistencies in the data related to age, gender, and survival status.

# %%
def age_category(age):
  if age<=10:
    category = '0-10'
  elif age <20:
    category ='11-20'
  elif age <=40:
    category = '21-40'
  elif age <=60:
    category ='41-60'
  else:
    category ='>60'
  return category

titanic['age_category'] = titanic.apply(lambda x: age_category(x['age']),axis=1)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_category
# 0    man        True  NaN  Southampton    no  False        21-40
# 1  woman       False    C    Cherbourg   yes  False        21-40
# 2  woman       False  NaN  Southampton   yes   True        21-40
# 3  woman       False    C  Southampton   yes  False        21-40
# 4    man        True  NaN  Southampton    no   True        21-40

# %%
sns.boxplot(data=titanic,y='age',x='sex',hue='alive')
plt.title("Distribution of age by gender and survival status")
plt.show()

# %% [markdown]
# Q.6 Create data visualizations: Use Seaborn to create appropriate visualizations such as bar charts, count plots, or heatmaps to explore the relationship between age, gender, and survival status of the passengers on the Titanic.

# %%
age_sex_alive = titanic[['age','sex','alive']]
graph = sns.countplot(data=age_sex_alive,x='sex',hue='alive')

for p in graph.patches:
  height = p.get_height()
  graph.text(p.get_x() + p.get_width()/2,height+5,height,ha='center',fontsize=10)
plt.title("Count of people Survived or not by gender")
plt.show()

# %% [markdown]
# Q.7 Interpretation: Based on the visualizations, draw conclusions and insights about the relationship between age, gender, and survival status of the passengers on the Titanic.

# %%
# in the dataset more survived people are female.

# %% [markdown]
# ## **Activity 4:**

# %% [markdown]
# ### **Iris Species:**
#
#
# 👉 Instructions:
# 1. You have a dataset containing information about various iris flowers, including sepal length, sepal width, petal length, petal width, and species. Your task is to use the Seaborn library in Python to create visualizations and gain insights from the data.
#
# 2. Load the dataset: Load the "Iris Species" dataset using Seaborn's built-in function load_dataset().
#
# 3. Explore the data: Use Seaborn's functions such as head(), info(), and describe() to explore the dataset and understand its structure, contents, and data types.
#
# 4. Data visualization: Create various visualizations using Seaborn's functions such as scatterplot(), boxplot(), violinplot(), pairplot(), heatmap(), etc. to visualize the relationships between different variables and gain insights from the data. Experiment with different types of visualizations to explore different aspects of the data.
#
# 5. Customizations: Customize your visualizations using Seaborn's built-in functions for changing colors, styles, labels, titles, etc. to make your visualizations more informative and visually appealing.
#
# 6. Interpretation: Based on the visualizations, analyze and interpret the patterns, trends, and relationships in the data. Draw conclusions and insights from the visualizations and present your findings in a clear and concise manner.
#
# **Note:** Make sure to use appropriate Seaborn functions for each type of visualization and follow best practices for data visualization, including labeling axes, adding titles, using appropriate colors, and choosing the right type of plot for your data.

# %% [markdown]
# ![iris.png](data:image/png;base64,...)

# %%
# Write your code here
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# Explore the data: Use Seaborn's functions such as head(), info(), and describe() to explore the dataset and understand its structure, contents, and data types

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# how many iris category
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.value_counts("species") # in 3 species equal samples are present
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# Average sepal and petal length and width for each species

# %%
iris.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# Data visualization: Create various visualizations using Seaborn's functions such as scatterplot(), boxplot(), violinplot(), pairplot(), heatmap(), etc. to visualize the relationships between different variables and gain insights from the data. Experiment with different types of visualizations to explore different aspects of the data.

# %%
sns.scatterplot(data=iris,x='sepal_length',y='sepal_width',hue='species')
plt.title('Sepal Length vs. Sepal Width')
plt.show()

# %%
sns.scatterplot(data=iris,x='petal_length',y='petal_width',hue='species')
plt.title('Petal Length vs. Petal Width')
plt.show()

# %%
sns.boxplot(data=iris,y='sepal_length',x='species')
plt.title('Distribution of sepal length by species')
plt.show()

# %%
sns.boxplot(data=iris,y='sepal_width',x='species')
plt.title('Distribution of sepal width by species')
plt.show()

# %%
sns.boxplot(data=iris,y='petal_length',x='species')
plt.title('Distribution of petal length by species')
plt.show()

# %%
sns.boxplot(data=iris,y='petal_width',x='species')
plt.title('Distribution of  petal width by species')
plt.show()

# %%
sns.violinplot(data=iris, x="species", y="petal_width")
plt.title("Violinplot of Petal Width by Species")
plt.show()

# %%
sns.pairplot(iris,hue='species')
plt.show()

# %%
iris.corr()
# Out:
# <ipython-input-18-156dd03bc859>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(),annot=True)
plt.show()
# Heatmap reveals the strong positive correlation petal length and petal width
# Out:
# <ipython-input-20-8af1268bf5ed>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),annot=True)
